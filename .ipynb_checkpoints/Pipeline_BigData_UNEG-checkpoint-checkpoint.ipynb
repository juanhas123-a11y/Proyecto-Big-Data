# %%
import sys
# Instalación de librerías necesarias para la conectividad y procesamiento
# !{sys.executable} -m pip install cassandra-driver clickhouse-driver clickhouse-connect pandas numpy
# Out:
# Requirement already satisfied: cassandra-driver in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (3.29.3)
# Requirement already satisfied: clickhouse-driver in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (0.2.10)
# Requirement already satisfied: clickhouse-connect in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (0.10.0)
# Requirement already satisfied: pandas in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (2.4.1)
# Requirement already satisfied: geomet>=1.1 in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from cassandra-driver) (1.1.0)
# Requirement already satisfied: pytz in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from clickhouse-driver) (2025.2)
# Requirement already satisfied: tzlocal in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from clickhouse-driver) (5.3.1)
# Requirement already satisfied: certifi in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from clickhouse-connect) (2026.1.4)
# Requirement already satisfied: urllib3>=1.26 in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from clickhouse-connect) (2.6.3)
# Requirement already satisfied: zstandard in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from clickhouse-connect) (0.25.0)
# Requirement already satisfied: lz4 in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from clickhouse-connect) (4.4.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: click in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from geomet>=1.1->cassandra-driver) (8.3.1)
# Requirement already satisfied: six>=1.5 in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\juanh\appdata\local\programs\python\python313\lib\site-packages (from click->geomet>=1.1->cassandra-driver) (0.4.6)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
import types

# Simulación del módulo 'asyncore' requerido por cassandra-driver en versiones recientes de Python
mock_as = types.ModuleType('asyncore')
class MockDispatcher:
    def __init__(self, *args, **kwargs): pass
    def close(self): pass
    def add_channel(self, map=None): pass
    def del_channel(self, map=None): pass
mock_as.dispatcher = MockDispatcher
mock_as.socket_map = {}
sys.modules['asyncore'] = mock_as

print("✅ Entorno de compatibilidad configurado.")
# Out:
# ✅ Entorno de compatibilidad configurado.

# %%
import subprocess

print("🏗️ Configurando Keyspace y Tablas en Cassandra...")

commands = [
    "CREATE KEYSPACE IF NOT EXISTS proyecto_bigdata WITH replication = {'class': 'SimpleStrategy', 'replication_factor': 1};",
    "CREATE TABLE IF NOT EXISTS proyecto_bigdata.ventas_crudas (id int PRIMARY KEY, categoria text, precio float, fecha timestamp);"
]

for cmd in commands:
    subprocess.run(["docker", "exec", "cassandra_db", "cqlsh", "-e", cmd], check=True)

print("✅ Infraestructura de Cassandra lista.")
# Out:
# 🏗️ Configurando Keyspace y Tablas en Cassandra...
# ✅ Infraestructura de Cassandra lista.

# %%
import pandas as pd
import numpy as np
import subprocess
import os

print("⏳ Generando 100,000 registros sintéticos...")
df = pd.DataFrame({
    'id': range(1, 100001),
    'categoria': np.random.choice(['Electronica', 'Hogar'], 100000),
    'precio': np.random.uniform(50, 550, 100000).round(2),
    'fecha': pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')
})

# Cálculo del resumen (Agregación)
resumen = df.groupby('categoria').agg(
    total_ventas=('precio', 'sum'),
    cantidad_transacciones=('precio', 'count')
).reset_index()

csv_file = 'datos_carga.csv'
df.to_csv(csv_file, index=False, header=False)

try:
    print("📦 Transfiriendo y cargando datos en Cassandra...")
    subprocess.run(["docker", "cp", csv_file, "cassandra_db:/tmp/datos.csv"], check=True)
    
    cql_cmd = "COPY proyecto_bigdata.ventas_crudas (id, categoria, precio, fecha) FROM '/tmp/datos.csv' WITH DELIMITER=',' AND HEADER=FALSE;"
    
    result = subprocess.run(["docker", "exec", "cassandra_db", "cqlsh", "-e", cql_cmd], capture_output=True, text=True)

    if result.returncode == 0:
        print("✅ Ingesta masiva completada exitosamente.")
    else:
        print(f"❌ Error en carga: {result.stderr}")
    
    os.remove(csv_file)
except Exception as e:
    print(f"❌ Error de ejecución: {e}")
# Out:
# ⏳ Generando 100,000 registros sintéticos...
# 📦 Transfiriendo y cargando datos en Cassandra...
# ✅ Ingesta masiva completada exitosamente.

# %%
import clickhouse_connect

print("🚀 Procesando y enviando reporte a ClickHouse...")

try:
    client = clickhouse_connect.get_client(
        host='127.0.0.1', 
        port=8123, 
        username='default', 
        password='1234'
    )
    
    # Configuración de la tabla analítica
    client.command('DROP TABLE IF EXISTS ventas_resumen')
    client.command('''
        CREATE TABLE ventas_resumen (
            categoria String, 
            total_ventas Float64, 
            cantidad_transacciones UInt64
        ) ENGINE = Memory
    ''')

    # Carga de datos agregados
    client.insert_df('ventas_resumen', resumen)

    print("🏁 Pipeline finalizado. Resultados en ClickHouse:")
    
    # Consulta de validación
    resultado = client.query('SELECT * FROM ventas_resumen')
    df_res = pd.DataFrame(resultado.result_rows, columns=['Categoría', 'Ventas Totales', 'Transacciones'])
    display(df_res)

except Exception as e:
    print(f"❌ Error en fase final: {e}")
# Out:
# 🚀 Procesando y enviando reporte a ClickHouse...
# 🏁 Pipeline finalizado. Resultados en ClickHouse:
#      Categoría  Ventas Totales  Transacciones
# 0  Electronica     14994186.92          50038
# 1        Hogar     15041866.46          49962

# %%
import clickhouse_connect

client = clickhouse_connect.get_client(host='127.0.0.1', port=8123, username='default', password='1234')

# Consultar el resumen que acabamos de guardar
query_result = client.query('SELECT categoria, total_ventas FROM ventas_resumen WHERE total_ventas > 10000000')

print("🏆 Categorías con ventas superiores a 10M:")
for row in query_result.result_rows:
    print(f"La categoría {row[0]} es líder con ${row[1]:,.2f}")
# Out:
# 🏆 Categorías con ventas superiores a 10M:
# La categoría Electronica es líder con $14,994,186.92
# La categoría Hogar es líder con $15,041,866.46

# %%
import subprocess
import pandas as pd
import clickhouse_connect
from IPython.display import display, HTML

print("🔄 Sincronizando vistas de Cassandra y ClickHouse...")

try:
    # --- 1. OBTENER DATOS DE CASSANDRA (Mediante consulta directa) ---
    # Pedimos los datos en formato simple
    cmd_cas = 'docker exec cassandra_db cqlsh -e "SELECT id, categoria, precio, fecha FROM proyecto_bigdata.ventas_crudas LIMIT 5;"'
    res_cas = subprocess.run(cmd_cas, shell=True, capture_output=True, text=True)
    
    # --- 2. OBTENER DATOS DE CLICKHOUSE ---
    client = clickhouse_connect.get_client(host='127.0.0.1', port=8123, username='default', password='1234')
    res_ch = client.query('SELECT * FROM ventas_resumen')
    df_clickhouse = pd.DataFrame(res_ch.result_rows, columns=['Categoría', 'Total Ventas', 'Transacciones'])

    # --- 3. MOSTRAR AMBAS VISTAS ---
    
    # Vista de Cassandra (Como texto preformateado para evitar errores de parseo)
    display(HTML("<h3 style='color: #2e7d32;'>📁 ORIGEN: Cassandra (Muestra de registros crudos)</h3>"))
    if res_cas.stdout:
        print(res_cas.stdout)
    else:
        print("⚠️ No se recibieron datos de Cassandra. Verifica que la tabla tenga registros.")

    display(HTML("<br><h3 style='color: #1565c0;'>📊 DESTINO: ClickHouse (Reporte consolidado final)</h3>"))
    # Formateo estético para ClickHouse
    df_clickhouse['Total Ventas'] = df_clickhouse['Total Ventas'].map('${:,.2f}'.format)
    df_clickhouse['Transacciones'] = df_clickhouse['Transacciones'].map('{:,}'.format)
    display(df_clickhouse)

except Exception as e:
    print(f"❌ Error general: {e}")
# Out:
# 🔄 Sincronizando vistas de Cassandra y ClickHouse...
# <h3 style='color: #2e7d32;'>📁 ORIGEN: Cassandra (Muestra de registros crudos)</h3>
#  id    | categoria   | precio    | fecha
# -------+-------------+-----------+---------------------------------
#   4317 |       Hogar |    297.69 | 2026-01-31 19:21:06.000000+0000
#  62693 |       Hogar |    174.84 | 2026-01-31 19:21:06.000000+0000
#  51678 |       Hogar | 509.42999 | 2026-01-31 19:21:06.000000+0000
#  77328 | Electronica | 345.23999 | 2026-01-31 19:21:06.000000+0000
#  84757 | Electronica |    207.95 | 2026-01-31 19:21:06.000000+0000
#
# (5 rows)
# <br><h3 style='color: #1565c0;'>📊 DESTINO: ClickHouse (Reporte consolidado final)</h3>
#      Categoría    Total Ventas Transacciones
# 0  Electronica  $14,994,186.92        50,038
# 1        Hogar  $15,041,866.46        49,962
